# %% [markdown]
# # Reporte de Análisis V

# %% [markdown]
# ## Tratamiento de Datos Faltantes

# %%
import pandas as pd

# %%
datos = pd.read_csv("Pandas/data/alquiler_residencial.csv", sep = ";")

# %%
datos.head(10)
# Out:
#                  Tipo     Distrito  Cuartos  Vacantes  Suites  Area    Valor  \
# 0          Habitación    San Borja        1         0       0    40   1700.0
# 1                Casa   Lurigancho        2         0       1   100   7000.0
# 2        Departamento   Pachacámac        1         0       0    15    800.0
# 3        Departamento          Ate        1         0       0    48    800.0
# 4        Departamento     Barranco        3         1       0    70   1200.0
# 5        Departamento        Comas        2         0       0    50   1300.0
# 6  Casa en condominio          Ate        5         4       5   750  22000.0
# 7  Casa en condominio  El Agustino        2         2       0    65   1000.0
# 8        Departamento   Pachacámac        1         0       0    36   1200.0
# 9        Departamento      Mi Perú        2         1       0    70   1500.0
#
#    Mantenimiento  Impuesto
# 0          500.0      60.0
# 1            NaN       NaN
# 2          390.0      20.0
# 3          230.0       NaN
# 4            NaN       NaN
# 5          301.0      17.0
# 6            NaN       NaN
# 7            NaN       NaN
# 8            NaN       NaN
# 9          642.0      74.0

# %%
datos.isnull()
# Out:
#         Tipo  Distrito  Cuartos  Vacantes  Suites   Area  Valor  \
# 0      False     False    False     False   False  False  False
# 1      False     False    False     False   False  False  False
# 2      False     False    False     False   False  False  False
# 3      False     False    False     False   False  False  False
# 4      False     False    False     False   False  False  False
# ...      ...       ...      ...       ...     ...    ...    ...
# 23463  False     False    False     False   False  False  False
# 23464  False     False    False     False   False  False  False
# 23465  False     False    False     False   False  False  False
# 23466  False     False    False     False   False  False  False
# 23467  False     False    False     False   False  False  False
#
#        Mantenimiento  Impuesto
# 0              False     False
# 1               True      True
# 2              False     False
# 3              False      True
# 4               True      True
# ...              ...       ...
# 23463          False     False
# 23464          False     False
# 23465          False     False
# 23466          False     False
# 23467          False      True
#
# [23468 rows x 9 columns]

# %%
datos.notnull()
# Out:
#        Tipo  Distrito  Cuartos  Vacantes  Suites  Area  Valor  Mantenimiento  \
# 0      True      True     True      True    True  True   True           True
# 1      True      True     True      True    True  True   True          False
# 2      True      True     True      True    True  True   True           True
# 3      True      True     True      True    True  True   True           True
# 4      True      True     True      True    True  True   True          False
# ...     ...       ...      ...       ...     ...   ...    ...            ...
# 23463  True      True     True      True    True  True   True           True
# 23464  True      True     True      True    True  True   True           True
# 23465  True      True     True      True    True  True   True           True
# 23466  True      True     True      True    True  True   True           True
# 23467  True      True     True      True    True  True   True           True
#
#        Impuesto
# 0          True
# 1         False
# 2          True
# 3         False
# 4         False
# ...         ...
# 23463      True
# 23464      True
# 23465      True
# 23466      True
# 23467     False
#
# [23468 rows x 9 columns]

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23468 entries, 0 to 23467
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           23468 non-null  object
#  1   Distrito       23468 non-null  object
#  2   Cuartos        23468 non-null  int64
#  3   Vacantes       23468 non-null  int64
#  4   Suites         23468 non-null  int64
#  5   Area           23468 non-null  int64
#  6   Valor          23459 non-null  float64
#  7   Mantenimiento  20864 non-null  float64
#  8   Impuesto       16350 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.6+ MB

# %%
datos[datos["Valor"].isnull()]
# Out:
#               Tipo     Distrito  Cuartos  Vacantes  Suites  Area  Valor  \
# 58    Departamento          Ate        2         1       1    70    NaN
# 1561  Departamento  San Bartolo        2         0       0    75    NaN
# 1757          Casa        Lince        3         4       3   363    NaN
# 2097  Departamento   Chorrillos        2         0       0    95    NaN
# 2119  Departamento    San Borja        2         0       0    72    NaN
# 5130          Casa        Lince        3         2       1   100    NaN
# 8912  Departamento  San Bartolo        2         0       1    75    NaN
# 9309  Departamento     La Punta        3         0       1   135    NaN
# 9517  Departamento     La Perla        3         1       1   105    NaN
#
#       Mantenimiento  Impuesto
# 58            970.0      68.0
# 1561          878.0       NaN
# 1757            NaN       NaN
# 2097         1010.0     170.0
# 2119          850.0       NaN
# 5130            NaN       NaN
# 8912          878.0       NaN
# 9309          910.0     228.0
# 9517          880.0     221.0

# %%
A = datos.shape[0]
datos.dropna(subset=["Valor"], inplace = True)
B = datos.shape[0]
A - B
# Out:
# 9

# %%
datos[datos["Valor"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Tipo, Distrito, Cuartos, Vacantes, Suites, Area, Valor, Mantenimiento, Impuesto]
# Index: []

# %% [markdown]
# ## Tratamiento de Datos Faltantes(continuacion)

# %%
datos
# Out:
#                Tipo     Distrito  Cuartos  Vacantes  Suites  Area   Valor  \
# 0        Habitación    San Borja        1         0       0    40  1700.0
# 1              Casa   Lurigancho        2         0       1   100  7000.0
# 2      Departamento   Pachacámac        1         0       0    15   800.0
# 3      Departamento          Ate        1         0       0    48   800.0
# 4      Departamento     Barranco        3         1       0    70  1200.0
# ...             ...          ...      ...       ...     ...   ...     ...
# 23463  Departamento  Santa Anita        2         0       0    70   900.0
# 23464    Habitación   Pachacámac        0         0       0    27   800.0
# 23465  Departamento        Lince        3         1       2    78  1800.0
# 23466  Departamento        Rímac        2         1       0    48  1400.0
# 23467  Departamento        Rímac        2         0       0    70  3000.0
#
#        Mantenimiento  Impuesto
# 0              500.0      60.0
# 1                NaN       NaN
# 2              390.0      20.0
# 3              230.0       NaN
# 4                NaN       NaN
# ...              ...       ...
# 23463          490.0      48.0
# 23464          350.0      25.0
# 23465          800.0      40.0
# 23466          509.0      37.0
# 23467          760.0       NaN
#
# [23459 rows x 9 columns]

# %%
datos[datos["Mantenimiento"].isnull()].shape[0]
# Out:
# 2602

# %%
seleccion = (datos["Mantenimiento"].isnull()) & (datos["Tipo"] == "Departamento")

# %%
A = datos.shape[0]
datos = datos[~seleccion]
B = datos.shape[0]
A - B
# Out:
# 745

# %%
datos[datos["Mantenimiento"].isnull()].shape[0]
# Out:
# 1857

# %%
datos = datos.fillna({"Mantenimiento":0, "Impuesto":0})

# %%
datos[datos["Mantenimiento"].isnull()].shape[0]
# Out:
# 0

# %%
datos[datos["Impuesto"].isnull()].shape[0]
# Out:
# 0

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22714 entries, 0 to 23467
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           22714 non-null  object
#  1   Distrito       22714 non-null  object
#  2   Cuartos        22714 non-null  int64
#  3   Vacantes       22714 non-null  int64
#  4   Suites         22714 non-null  int64
#  5   Area           22714 non-null  int64
#  6   Valor          22714 non-null  float64
#  7   Mantenimiento  22714 non-null  float64
#  8   Impuesto       22714 non-null  float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 1.7+ MB

# %%
datos.to_csv("Pandas/data/alquiler_residencial.csv", sep = ";", index = False)
